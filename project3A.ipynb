# %%
import pandas as pd
ads_data = pd.read_csv("data_SocialMediaAds.csv")
ads_data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
import pandas as pd
ads_data = pd.read_csv("data_SocialMediaAds.csv")
X = ads_data[['Gender','Age','EstimatedSalary']]
X
# Out:
#      Gender  Age  EstimatedSalary
# 0      Male   19            19000
# 1      Male   35            20000
# 2    Female   26            43000
# 3    Female   27            57000
# 4      Male   19            76000
# ..      ...  ...              ...
# 395  Female   46            41000
# 396    Male   51            23000
# 397  Female   50            20000
# 398    Male   36            33000
# 399  Female   49            36000
#
# [400 rows x 3 columns]

# %%
import pandas as pd
ads_data = pd.read_csv("data_SocialMediaAds.csv")
X = ads_data[['Gender','Age','EstimatedSalary']]
y = ads_data['Purchased']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier


ads_data = pd.read_csv("data_SocialMediaAds.csv")
ads_data['Gender'] = ads_data['Gender'].map({'Male': 1, 'Female': 0})

X = ads_data[['Gender','Age','EstimatedSalary']]
y = ads_data['Purchased']

model = KNeighborsClassifier(n_neighbors=10)
model.fit(X, y)

prediction = model.predict([[1, 23, 5000]])
prediction
# Out:
# C:\Users\goswa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score


ads_data = pd.read_csv("data_SocialMediaAds.csv")
ads_data['Gender'] = ads_data['Gender'].map({'Male': 1, 'Female': 0})

X = ads_data[['Gender','Age','EstimatedSalary']]
y = ads_data['Purchased']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

model = KNeighborsClassifier(n_neighbors=9)
model.fit(X_train, y_train)
prediction = model.predict(X_test)

ads_data = pd.read_csv("data_SocialMediaAds.csv")
ads_data['Gender'] = ads_data['Gender'].map({'Male': 1, 'Female': 0})

purchased = ads_data[ads_data['Purchased'] == 1]
not_purchased = ads_data[ads_data['Purchased'] == 0]

plt.figure(figsize=(5, 3))
plt.scatter(purchased['Age'], purchased['EstimatedSalary'], color='green', label='Purchased', alpha=0.4)
plt.scatter(not_purchased['Age'], not_purchased['EstimatedSalary'], color='red', label='Not Purchased', alpha=0.4)

plt.xlabel("Age")
plt.ylabel("Estimated Salary")

accuracy = accuracy_score(y_test, prediction)
precision = precision_score(y_test, prediction)
recall = recall_score(y_test, prediction)
f1 = f1_score(y_test, prediction)

print("Accuracy = ", accuracy)
print("Precision = ", precision)
print("Recall = ", recall)
print("F1-score = ", f1)
# Out:
# Accuracy =  0.8125
# Precision =  0.6896551724137931
# Recall =  0.7692307692307693
# F1-score =  0.7272727272727273

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

ads_data = pd.read_csv("data_SocialMediaAds.csv")
ads_data['Gender'] = ads_data['Gender'].map({'Male': 1, 'Female': 0})

X = ads_data[['Gender','Age','EstimatedSalary']]
y = ads_data['Purchased']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

model = KNeighborsClassifier(n_neighbors=9)
model.fit(X_train, y_train)
prediction = model.predict(X_test)

ads_data = pd.read_csv("data_SocialMediaAds.csv")
ads_data['Gender'] = ads_data['Gender'].map({'Male': 1, 'Female': 0})

male_data = ads_data[ads_data['Gender'] == 1]
female_data = ads_data[ads_data['Gender'] == 0]

male_purchased = male_data[male_data['Purchased'] == 1]
male_not_purchased = male_data[male_data['Purchased'] == 0]

plt.figure(figsize=(5, 3))
plt.title("Male Users: Age vs Estimated Salary")
plt.scatter(male_purchased['Age'], male_purchased['EstimatedSalary'], color='green', label='Purchased', alpha=0.4)
plt.scatter(male_not_purchased['Age'], male_not_purchased['EstimatedSalary'], color='red', label='Not Purchased', alpha=0.4)
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.legend()
plt.grid(True)
plt.show()

female_purchased = female_data[female_data['Purchased'] == 1]
female_not_purchased = female_data[female_data['Purchased'] == 0]

plt.figure(figsize=(5, 3))
plt.title("Female Users: Age vs Estimated Salary")
plt.scatter(female_purchased['Age'], female_purchased['EstimatedSalary'], color='green', label='Purchased', alpha=0.4)
plt.scatter(female_not_purchased['Age'], female_not_purchased['EstimatedSalary'], color='red', label='Not Purchased', alpha=0.4)
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.legend()
plt.grid(True)
plt.show()

accuracy = accuracy_score(y_test, prediction)
precision = precision_score(y_test, prediction)
recall = recall_score(y_test, prediction)
f1 = f1_score(y_test, prediction)

print("Accuracy = ", accuracy)
print("Precision = ", precision)
print("Recall = ", recall)
print("F1-score = ", f1)
# Out:
# Accuracy =  0.825
# Precision =  0.8636363636363636
# Recall =  0.6333333333333333
# F1-score =  0.7307692307692307
