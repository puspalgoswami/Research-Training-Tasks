# %%
import pandas as pd
life = pd.read_csv("dataLifeExpt.csv")
life
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
import pandas as pd
life = pd.read_csv("dataLifeExpt.csv")

X = life.drop(columns=['Status', 'Life expectancy'])
X
# Out:
#           Country  Year  Adult Mortality  Infant deaths  Alcohol  \
# 0     Afghanistan  2015            263.0             62     0.01
# 1     Afghanistan  2014            271.0             64     0.01
# 2     Afghanistan  2013            268.0             66     0.01
# 3     Afghanistan  2012            272.0             69     0.01
# 4     Afghanistan  2011            275.0             71     0.01
# ...           ...   ...              ...            ...      ...
# 2933     Zimbabwe  2004            723.0             27     4.36
# 2934     Zimbabwe  2003            715.0             26     4.06
# 2935     Zimbabwe  2002             73.0             25     4.43
# 2936     Zimbabwe  2001            686.0             25     1.72
# 2937     Zimbabwe  2000            665.0             24     1.68
#
#       Percentage expenditure  Hepatitis B  Measles   BMI  Under-five deaths  \
# 0                  71.279624         65.0     1154  19.1                 83
# ...

# %%
import pandas as pd
life = pd.read_csv("dataLifeExpt.csv")

X = life.drop(columns=['Country', 'Year', 'Status', 'Life expectancy'])
y = life['Life expectancy']
y
# Out:
# 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
#         ...
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: Life expectancy, Length: 2938, dtype: float64

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

life = pd.read_csv("dataLifeExpt.csv")

life = life.dropna()
life['gdp_per_capita'] = (life['GDP'] / life['Population'])

life = life.drop(columns=['Country', 'Year', 'Status', 'GDP', 'Population'])

X = life.drop(columns=['Life expectancy'])
y = life['Life expectancy']

X
# Out:
#       Adult Mortality  Infant deaths  Alcohol  Percentage expenditure  \
# 0               263.0             62     0.01               71.279624
# 1               271.0             64     0.01               73.523582
# 2               268.0             66     0.01               73.219243
# 3               272.0             69     0.01               78.184215
# 4               275.0             71     0.01                7.097109
# ...               ...            ...      ...                     ...
# 2933            723.0             27     4.36                0.000000
# 2934            715.0             26     4.06                0.000000
# 2935             73.0             25     4.43                0.000000
# 2936            686.0             25     1.72                0.000000
# 2937            665.0             24     1.68                0.000000
#
#       Hepatitis B  Measles   BMI  Under-five deaths  Polio  Total expenditure  \
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

life = pd.read_csv("dataLifeExpt.csv")

life = life.dropna()
life['gdp_per_capita'] = (life['GDP'] / life['Population'])

life = life.drop(columns=['Country', 'Year', 'Status', 'GDP', 'Population'])

X = life.drop(columns=['Life expectancy'])
y = life['Life expectancy']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)

r2 = r2_score(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)

print("R2 score = ", r2)
print("Mean Absolute Error = ", mae)
print("Mean Squared Error = ", mse)

plt.figure(figsize=(6, 4.5))
plt.scatter(life['gdp_per_capita'], life['Life expectancy'], alpha=0.6, color='green', edgecolors='k')
plt.xlabel("GDP per Capita")
plt.ylabel("Life Expectancy")
plt.title("GDP per Capita vs Life Expectancy")
plt.tight_layout()
plt.show()
# Out:
# R2 score =  0.8023026324627109
# Mean Absolute Error =  2.7883931554342283
# Mean Squared Error =  12.548365476896633
